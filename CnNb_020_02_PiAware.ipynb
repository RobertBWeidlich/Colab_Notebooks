# %% [markdown]
# <a href="https://colab.research.google.com/github/RobertBWeidlich/Colab_Notebooks/blob/main/CnNb_020_02_PiAware.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Read a Piaware JSON data file, convert to a Python object,
# and do so simple analysis with Pandas.

# %%
# Download data
# !mkdir /content/data/
# !cd /content/data/
#!sftp user@X.X.X.X # this doesn't work...
# !ls -l
# !mget piaware-data-2024-10.tar

# %%
PIAWARE_DATA_DIR="/content/data/2024/"

import os

def list_files_recursively(directory):

    # Walk through the directory
    file_list = []
    for dirpath, dirnames, filenames in os.walk(directory):
        for filename in filenames:
            # Join the directory path with the file name to get the full path
            filepath = os.path.join(dirpath, filename)
            #print(filepath)
            file_list.append(filepath)
    return file_list

file_list = list_files_recursively(PIAWARE_DATA_DIR)
file_list_len = len(file_list)
print(f"{file_list_len} files in file_list")
# Out:
# 32957 files in file_list

# %%
# pick a random file
file_list_len = len(file_list)
file_index = int(file_list_len * 0.35)
print(file_list_len)
print(file_index)

pa_file = file_list[file_index]
print(f"pa_file: {pa_file}")
try:
  with open(pa_file, 'r') as file:
    # Read the contents of the file
    contents = file.read()
    # Print the file contents
    print(contents)
except FileNotFoundError:
  print(f"The file '{file_name}' was not found.")
except IOError:
  print(f"An error occurred while trying to read the file '{file_name}'.")
# Out:
# 32957
# 11534
# pa_file: /content/data/2024/10/04/11/piaware_raw-20241004.1158.40.015662.json
# { "now" : 1728057519.3,
#   "messages" : 2468159384,
#   "aircraft" : [
#     {"hex":"a9a541","alt_baro":40000,"version":0,"nac_p":8,"sil":2,"sil_type":"unknown","mlat":[],"tisb":[],"messages":11,"seen":6.3,"rssi":-17.5},
#     {"hex":"ac7e15","alt_baro":30000,"alt_geom":31375,"gs":405.9,"track":229.8,"baro_rate":0,"nav_qnh":1013.6,"nav_altitude_mcp":30016,"nav_heading":240.5,"lat":39.522291,"lon":-76.296387,"nic":8,"rc":186,"seen_pos":6.4,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":167,"seen":0.6,"rssi":-13.8},
#     {"hex":"a44e1c","flight":"DAL2411 ","alt_baro":34000,"alt_geom":35450,"gs":401.0,"track":236.4,"baro_rate":0,"squawk":"3054","emergency":"none","category":"A3","nav_qnh":1013.6,"nav_altitude_mcp":34016,"nav_heading":248.9,"lat":39.903854,"lon":-76.189171,"nic":8,"rc":186,"seen_pos":22.4,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":296,"seen":16.8,"rssi":-16.4},
#     {"hex":"a6aac2","flight":"JIA5180 ","alt_baro":34000,"alt_geom":35675,"gs":503.3,"track":32.2,"geom_rate":0,"squawk":"2257","emergency":"none","category":"A3","nav_qnh":1012.8,"nav_altitude_mcp":34016,"nav_heading":33.0,"lat":38.113358,"lon":-76.661137,"nic":8,"rc":186,"seen_pos":1.5,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":648,"seen":1.3,"rssi":-16.5},
#     {"hex":"aa9f6f","alt_baro":38000,"alt_geom":39600,"gs":416.4,"track":230.7,"baro_rate":0,"squawk":"2420","emergency":"none","nav_qnh":1012.8,"nav_altitude_mcp":38016,"nav_heading":248.2,"lat":39.599808,"lon":-76.177109,"nic":8,"rc":186,"seen_pos":0.4,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":179,"seen":0.4,"rssi":-12.8},
#     {"hex":"a4ee36","alt_baro":18500,"squawk":"2641","emergency":"none","version":0,"nac_p":8,"sil":2,"sil_type":"unknown","mlat":[],"tisb":[],"messages":36,"seen":6.3,"rssi":-16.9},
#     {"hex":"a7869b","alt_baro":35000,"alt_geom":36625,"gs":455.1,"track":347.3,"baro_rate":0,"nav_qnh":1013.6,"nav_altitude_mcp":35008,"lat":38.637100,"lon":-78.142334,"nic":8,"rc":186,"seen_pos":1.1,"version":0,"nic_baro":1,"nac_p":8,"nac_v":1,"sil":2,"sil_type":"unknown","mlat":[],"tisb":[],"messages":61,"seen":1.1,"rssi":-16.4},
#     {"hex":"a699b0","flight":"VOS4326 ","alt_baro":3775,"alt_geom":4075,"gs":251.1,"track":1.6,"baro_rate":0,"squawk":"2707","emergency":"none","category":"A3","nav_qnh":1022.4,"nav_altitude_mcp":4000,"lat":38.827240,"lon":-77.355214,"nic":8,"rc":186,"seen_pos":0.0,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":346,"seen":0.0,"rssi":-9.2},
#     {"hex":"ae2fd3","alt_baro":21750,"alt_geom":22850,"gs":182.9,"track":218.6,"baro_rate":0,"nav_qnh":1021.6,"nav_altitude_fms":21888,"nav_heading":0.0,"lat":38.477799,"lon":-75.980286,"nic":8,"rc":186,"seen_pos":5.2,"version":0,"nic_baro":1,"nac_p":8,"nac_v":4,"sil":2,"sil_type":"unknown","mlat":[],"tisb":[],"messages":63,"seen":4.6,"rssi":-15.3},
#     {"hex":"a05470","flight":"RPA4418 ","alt_baro":34000,"alt_geom":35350,"gs":395.2,"track":236.4,"baro_rate":64,"category":"A3","nav_qnh":1013.6,"nav_altitude_mcp":34016,"nav_modes":["autopilot","vnav","tcas"],"lat":39.798020,"lon":-76.395691,"nic":8,"rc":186,"seen_pos":0.9,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":331,"seen":0.0,"rssi":-11.7},
#     {"hex":"abd230","flight":"SWA3094 ","alt_baro":12725,"alt_geom":13275,"gs":365.1,"track":271.4,"baro_rate":3392,"squawk":"6236","emergency":"none","category":"A3","nav_qnh":1022.4,"nav_altitude_mcp":23008,"nav_heading":340.3,"lat":39.221191,"lon":-77.043059,"nic":8,"rc":186,"seen_pos":1.9,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":706,"seen":0.4,"rssi":-8.6},
#     {"hex":"abb8c4","flight":"SWA3319 ","alt_baro":24425,"alt_geom":25675,"gs":458.9,"track":72.6,"baro_rate":-2112,"squawk":"6775","emergency":"none","category":"A3","lat":38.551849,"lon":-78.225224,"nic":8,"rc":186,"seen_pos":1.8,"version":2,"nac_v":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":60,"seen":1.3,"rssi":-16.5},
#     {"hex":"abe82c","category":"A3","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":111,"seen":147.2,"rssi":-15.2},
#     {"hex":"a01f73","flight":"RPA4421 ","alt_baro":8750,"alt_geom":9250,"gs":296.5,"track":26.7,"baro_rate":-64,"squawk":"4607","emergency":"none","category":"A3","nav_qnh":1022.4,"nav_altitude_mcp":9024,"nav_modes":["autopilot","althold","tcas"],"lat":38.723373,"lon":-77.042820,"nic":8,"rc":186,"seen_pos":8.7,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":1252,"seen":6.6,"rssi":-14.2},
#     {"hex":"a79821","flight":"JBU698  ","alt_baro":36175,"alt_geom":37950,"gs":485.2,"track":26.8,"baro_rate":-960,"squawk":"0722","emergency":"none","category":"A3","nav_qnh":1013.6,"nav_altitude_mcp":31008,"nav_heading":0.0,"lat":38.198625,"lon":-76.473979,"nic":8,"rc":186,"seen_pos":1.2,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":1189,"seen":0.3,"rssi":-16.0},
#     {"hex":"ac2f18","version":0,"sil_type":"unknown","mlat":[],"tisb":[],"messages":21,"seen":125.9,"rssi":-18.0},
#     {"hex":"a0d72b","flight":"AAL1379 ","alt_baro":35025,"alt_geom":36700,"gs":503.2,"track":32.6,"baro_rate":0,"squawk":"6051","emergency":"none","category":"A3","nav_qnh":1013.6,"nav_altitude_mcp":35008,"lat":38.313190,"lon":-76.506401,"nic":8,"rc":186,"seen_pos":12.6,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":1340,"seen":0.8,"rssi":-17.4},
#     {"hex":"a03510","flight":"EJA112  ","alt_baro":3100,"alt_geom":3350,"gs":274.1,"track":1.5,"geom_rate":-896,"squawk":"0570","emergency":"none","category":"A3","nav_qnh":1022.4,"nav_altitude_mcp":3008,"nav_heading":12.0,"lat":38.947906,"lon":-77.350796,"nic":8,"rc":186,"seen_pos":0.4,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":1412,"seen":0.1,"rssi":-4.1},
#     {"hex":"a3298a","flight":"JBU1310 ","alt_baro":35000,"alt_geom":36675,"gs":489.9,"track":32.7,"geom_rate":-64,"squawk":"0745","category":"A3","nav_qnh":1012.8,"nav_altitude_mcp":35008,"nav_heading":36.6,"lat":38.002396,"lon":-76.766091,"nic":8,"rc":186,"seen_pos":0.2,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":194,"seen":0.1,"rssi":-13.7},
#     {"hex":"acd964","flight":"AAL2332 ","alt_baro":27775,"alt_geom":29125,"gs":415.1,"track":225.3,"baro_rate":1408,"squawk":"1102","emergency":"none","category":"A3","nav_qnh":1013.6,"nav_altitude_mcp":32000,"nav_heading":237.0,"lat":39.224310,"lon":-76.698486,"nic":8,"rc":186,"seen_pos":0.3,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":870,"seen":0.2,"rssi":-9.3},
#     {"hex":"a4bfc7","flight":"LXJ405  ","alt_baro":42975,"alt_geom":44600,"gs":382.9,"track":220.8,"geom_rate":0,"squawk":"1136","emergency":"none","category":"A2","nav_qnh":1012.8,"nav_altitude_mcp":43008,"nav_heading":240.5,"lat":39.356049,"lon":-76.698602,"nic":8,"rc":186,"seen_pos":9.8,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":581,"seen":8.9,"rssi":-13.6},
#     {"hex":"ac28be","alt_baro":34000,"alt_geom":35400,"gs":401.0,"track":250.9,"baro_rate":0,"nav_qnh":1013.6,"nav_altitude_mcp":34016,"nav_heading":263.0,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","mlat":[],"tisb":[],"messages":107,"seen":7.1,"rssi":-17.6},
#     {"hex":"a6893c","flight":"JIA5640 ","alt_baro":12525,"alt_geom":13150,"gs":349.4,"track":335.1,"geom_rate":2048,"squawk":"3630","emergency":"none","category":"A2","nav_qnh":1022.4,"nav_altitude_mcp":12992,"lat":38.880020,"lon":-77.323210,"nic":8,"rc":186,"seen_pos":0.2,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":2774,"seen":0.1,"rssi":-2.9},
#     {"hex":"a05bde","flight":"RPA4373 ","alt_baro":13100,"alt_geom":13775,"gs":352.4,"track":59.3,"baro_rate":1856,"squawk":"5627","emergency":"none","category":"A3","nav_qnh":1022.4,"nav_altitude_mcp":19008,"nav_modes":["autopilot","vnav","tcas"],"lat":39.048250,"lon":-76.762146,"nic":8,"rc":186,"seen_pos":5.1,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":582,"seen":3.4,"rssi":-13.5},
#     {"hex":"a7e630","flight":"JIA5444 ","alt_baro":26125,"alt_geom":27375,"gs":397.7,"track":219.7,"geom_rate":1216,"squawk":"1105","emergency":"none","category":"A3","nav_qnh":1012.8,"nav_altitude_mcp":34016,"nav_heading":232.0,"lat":39.454239,"lon":-77.021086,"nic":8,"rc":186,"seen_pos":1.6,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":1452,"seen":0.1,"rssi":-9.7},
#     {"hex":"aaffaa","flight":"AAL1223 ","alt_baro":18575,"alt_geom":19400,"gs":384.1,"track":67.2,"baro_rate":2432,"category":"A3","nav_qnh":1012.8,"nav_altitude_mcp":20992,"lat":38.967621,"lon":-76.543701,"nic":8,"rc":186,"seen_pos":44.4,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":407,"seen":0.1,"rssi":-16.2},
#     {"hex":"a95635","flight":"N700SY  ","alt_baro":6750,"alt_geom":7175,"gs":238.4,"track":108.6,"baro_rate":0,"squawk":"4725","emergency":"none","category":"A1","nav_qnh":1022.4,"nav_altitude_mcp":7008,"lat":39.347907,"lon":-76.968079,"nic":9,"rc":75,"seen_pos":0.6,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":566,"seen":0.4,"rssi":-15.3},
#     {"hex":"ab7b8c","flight":"UAL674  ","alt_baro":35025,"alt_geom":36650,"gs":508.8,"track":37.3,"baro_rate":-64,"squawk":"3606","emergency":"none","category":"A3","nav_qnh":1012.8,"nav_altitude_mcp":27008,"lat":38.582308,"lon":-76.808533,"nic":8,"rc":186,"seen_pos":5.1,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":1549,"seen":0.2,"rssi":-12.2},
#     {"hex":"c05c86","alt_baro":9750,"alt_geom":10225,"gs":245.2,"track":151.8,"geom_rate":0,"squawk":"6246","emergency":"none","category":"A3","nav_qnh":1022.4,"nav_altitude_mcp":10016,"nav_heading":168.8,"lat":39.228287,"lon":-76.701647,"nic":8,"rc":186,"seen_pos":2.7,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":831,"seen":0.8,"rssi":-15.1},
#     {"hex":"a45e8a","version":0,"sil_type":"unknown","mlat":[],"tisb":[],"messages":37,"seen":256.0,"rssi":-17.7},
#     {"hex":"a53b26","category":"A1","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":20,"seen":248.4,"rssi":-18.1},
#     {"hex":"a6152a","alt_baro":33000,"alt_geom":34575,"gs":495.5,"track":37.7,"geom_rate":0,"category":"A3","lat":38.508058,"lon":-76.203186,"nic":8,"rc":186,"seen_pos":67.4,"version":2,"nac_v":1,"sil_type":"perhour","mlat":[],"tisb":[],"messages":1317,"seen":11.4,"rssi":-18.8},
#     {"hex":"aaa58b","flight":"UAL1044 ","alt_baro":10750,"alt_geom":11275,"gs":286.3,"track":177.6,"baro_rate":0,"squawk":"3263","emergency":"none","category":"A3","nav_qnh":1022.4,"nav_altitude_mcp":11008,"nav_heading":189.8,"lat":38.898056,"lon":-77.814849,"nic":8,"rc":186,"seen_pos":2.4,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":1303,"seen":0.1,"rssi":-11.5},
#     {"hex":"aaa326","flight":"AAL731  ","alt_baro":38000,"alt_geom":39625,"gs":408.0,"track":225.3,"baro_rate":0,"squawk":"2411","emergency":"none","category":"A5","nav_qnh":1012.8,"nav_altitude_mcp":38016,"nav_heading":241.9,"lat":39.255753,"lon":-76.657702,"nic":8,"rc":186,"seen_pos":0.2,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":3118,"seen":0.1,"rssi":-4.8},
#     {"hex":"a897f4","flight":"AAL1360 ","alt_baro":36000,"alt_geom":37600,"gs":407.9,"track":206.2,"baro_rate":0,"squawk":"2730","emergency":"none","category":"A3","nav_qnh":1012.8,"nav_altitude_mcp":36000,"lat":39.356146,"lon":-77.319885,"nic":8,"rc":186,"seen_pos":5.6,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":1746,"seen":3.7,"rssi":-10.6},
#     {"hex":"ab0d76","alt_baro":32000,"alt_geom":33350,"gs":412.0,"track":270.1,"baro_rate":0,"category":"A3","nav_qnh":1013.6,"nav_altitude_mcp":32000,"nav_heading":350.9,"lat":40.071794,"lon":-76.869028,"nic":8,"rc":186,"seen_pos":46.4,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","mlat":[],"tisb":[],"messages":1026,"seen":0.6,"rssi":-18.0},
#     {"hex":"a1623f","flight":"N189BL  ","alt_baro":30000,"alt_geom":31325,"gs":263.0,"track":242.9,"baro_rate":0,"squawk":"2762","emergency":"none","category":"A1","nav_qnh":1013.6,"nav_altitude_mcp":30016,"nav_heading":254.5,"nav_modes":["autopilot","althold","lnav"],"lat":39.310246,"lon":-78.038269,"nic":9,"rc":75,"seen_pos":1.8,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":2049,"seen":1.4,"rssi":-14.5},
#     {"hex":"aa763f","alt_baro":23100,"alt_geom":24350,"gs":447.5,"track":75.4,"baro_rate":-1856,"squawk":"5613","emergency":"none","category":"A3","nav_qnh":1012.8,"nav_altitude_mcp":15008,"lat":38.719638,"lon":-76.680847,"nic":8,"rc":186,"seen_pos":24.5,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","mlat":[],"tisb":[],"messages":2783,"seen":7.3,"rssi":-15.9},
#     {"hex":"a1ea70","alt_baro":19675,"alt_geom":20600,"gs":407.0,"track":243.1,"baro_rate":2240,"category":"A3","lat":38.486318,"lon":-77.808960,"nic":8,"rc":186,"seen_pos":4.6,"version":2,"nac_v":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":1623,"seen":4.3,"rssi":-16.2},
#     {"hex":"a677be","flight":"JIA5578 ","alt_baro":28275,"alt_geom":29600,"gs":392.7,"track":238.5,"geom_rate":832,"squawk":"3341","emergency":"none","category":"A2","nav_qnh":1012.8,"nav_altitude_mcp":34016,"lat":39.667674,"lon":-77.260193,"nic":8,"rc":186,"seen_pos":10.8,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":921,"seen":2.7,"rssi":-16.5},
#     {"hex":"a87876","flight":"GTI8839 ","alt_baro":3750,"category":"A5","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":99,"seen":47.9,"rssi":-15.9},
#     {"hex":"aa43c4","flight":"RPA3528 ","alt_baro":30975,"alt_geom":32325,"gs":495.9,"track":49.7,"baro_rate":-832,"squawk":"2171","emergency":"none","category":"A3","nav_qnh":1013.6,"nav_altitude_mcp":27008,"nav_modes":["autopilot","vnav","tcas"],"lat":38.853010,"lon":-76.723083,"nic":8,"rc":186,"seen_pos":1.9,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":3743,"seen":1.3,"rssi":-13.7},
#     {"hex":"acb1f8","category":"A2","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":2045,"seen":166.9,"rssi":-14.6},
#     {"hex":"a2da7f","flight":"PWR3    ","alt_baro":3775,"alt_geom":4025,"gs":234.3,"track":51.8,"geom_rate":-128,"squawk":"7324","emergency":"none","category":"A2","nav_qnh":1022.4,"nav_altitude_mcp":4000,"nav_heading":90.0,"lat":39.141495,"lon":-77.559715,"nic":8,"rc":186,"seen_pos":5.6,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":3646,"seen":0.3,"rssi":-12.8},
#     {"hex":"a1bd4d","flight":"AVL211  ","alt_baro":4750,"alt_geom":4950,"gs":101.1,"track":205.8,"baro_rate":-128,"squawk":"4642","emergency":"none","category":"A1","nav_qnh":1021.6,"nav_altitude_mcp":4992,"nav_heading":208.1,"lat":38.965527,"lon":-77.731689,"nic":9,"rc":75,"seen_pos":19.0,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":973,"seen":17.6,"rssi":-16.6},
#     {"hex":"a97310","alt_baro":28125,"category":"A3","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":1962,"seen":14.7,"rssi":-16.5},
#     {"hex":"adbaca","alt_baro":32000,"version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":126,"seen":11.8,"rssi":-18.7},
#     {"hex":"a38cd2","alt_baro":5750,"alt_geom":6100,"gs":232.6,"track":183.9,"baro_rate":0,"category":"A3","nav_qnh":1022.4,"nav_altitude_mcp":6016,"nav_modes":["autopilot","althold","tcas"],"lat":39.005701,"lon":-76.851562,"nic":8,"rc":186,"seen_pos":3.7,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":1558,"seen":3.2,"rssi":-16.3},
#     {"hex":"a4f1e5","flight":"AAL655  ","alt_baro":32000,"alt_geom":33425,"gs":410.2,"track":238.6,"baro_rate":0,"squawk":"1147","emergency":"none","category":"A3","nav_qnh":1012.8,"nav_altitude_mcp":32000,"lat":39.440173,"lon":-77.733337,"nic":8,"rc":186,"seen_pos":2.8,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":3,"mlat":[],"tisb":[],"messages":1440,"seen":2.4,"rssi":-9.3},
#     {"hex":"a071c8","flight":"DAL2412 ","alt_baro":38000,"alt_geom":39675,"gs":376.9,"track":225.1,"geom_rate":0,"squawk":"3350","emergency":"none","category":"A3","nav_qnh":1012.8,"nav_altitude_mcp":38016,"nav_heading":242.6,"lat":39.034836,"lon":-76.943406,"nic":8,"rc":186,"seen_pos":0.6,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":5175,"seen":0.2,"rssi":-10.6},
#     {"hex":"a40312","flight":"FFT3355 ","alt_baro":34025,"alt_geom":35600,"gs":407.3,"track":225.0,"baro_rate":0,"squawk":"2673","emergency":"none","category":"A3","nav_qnh":1012.8,"nav_altitude_mcp":34016,"lat":38.857498,"lon":-77.171611,"nic":8,"rc":186,"seen_pos":0.2,"version":2,"nic_baro":1,"nac_p":10,"nac_v":4,"sil":3,"sil_type":"perhour","gva":2,"sda":3,"mlat":[],"tisb":[],"messages":5146,"seen":0.0,"rssi":-4.9},
#     {"hex":"aca6c9","flight":"WMN914  ","alt_baro":32625,"alt_geom":34100,"gs":381.9,"track":253.4,"geom_rate":2176,"squawk":"7012","emergency":"none","category":"A2","nav_qnh":1012.8,"nav_altitude_mcp":34016,"nav_heading":265.1,"lat":38.901331,"lon":-78.004761,"nic":8,"rc":186,"seen_pos":0.3,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":6220,"seen":0.1,"rssi":-10.4},
#     {"hex":"a2147c","gs":507.4,"track":42.7,"baro_rate":-64,"category":"A3","version":2,"nac_v":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":1405,"seen":62.8,"rssi":-17.5},
#     {"hex":"ad33e7","flight":"N95SJ   ","alt_baro":1775,"alt_geom":1925,"gs":169.2,"track":182.7,"baro_rate":64,"squawk":"4177","emergency":"none","category":"A2","nav_qnh":1022.4,"nav_altitude_mcp":2016,"nav_modes":["autopilot","althold","tcas"],"lat":39.094711,"lon":-77.457196,"nic":8,"rc":186,"seen_pos":1.5,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":3346,"seen":0.7,"rssi":-10.9},
#     {"hex":"a2e516","flight":"N286JJ  ","alt_baro":25225,"alt_geom":26475,"gs":497.9,"track":45.8,"geom_rate":-2560,"squawk":"3443","emergency":"none","category":"A2","nav_qnh":1013.6,"nav_altitude_mcp":24000,"nav_heading":56.2,"lat":39.273972,"lon":-76.293600,"nic":8,"rc":186,"seen_pos":1.1,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":5443,"seen":0.2,"rssi":-12.4},
#     {"hex":"ae695e","alt_baro":16200,"mlat":[],"tisb":[],"messages":3954,"seen":0.1,"rssi":-13.7},
#     {"hex":"ac857b","category":"A2","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":2519,"seen":205.6,"rssi":-17.4},
#     {"hex":"a44b56","flight":"DAL1514 ","alt_baro":34000,"alt_geom":35625,"gs":408.7,"track":225.0,"baro_rate":0,"squawk":"1767","emergency":"none","category":"A3","nav_qnh":1013.6,"nav_altitude_mcp":34016,"nav_heading":0.0,"lat":38.750381,"lon":-77.308462,"nic":8,"rc":186,"seen_pos":0.1,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":7547,"seen":0.1,"rssi":-2.1},
#     {"hex":"a2e045","gs":506.7,"track":42.6,"baro_rate":-2560,"category":"A3","version":2,"nac_v":1,"sil_type":"perhour","mlat":[],"tisb":[],"messages":2760,"seen":69.5,"rssi":-15.9},
#     {"hex":"a19f29","category":"A3","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":667,"seen":138.0,"rssi":-17.9},
#     {"hex":"ab6906","category":"A1","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":5811,"seen":108.9,"rssi":-14.4},
#     {"hex":"a4ef54","gs":175.0,"track":233.1,"baro_rate":1152,"category":"A1","version":2,"nac_v":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":1734,"seen":29.4,"rssi":-16.1},
#     {"hex":"a64df2","category":"A2","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":1032,"seen":210.0,"rssi":-14.8},
#     {"hex":"ac98ac","category":"A3","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":2656,"seen":177.1,"rssi":-13.9},
#     {"hex":"a4105b","category":"A3","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":2105,"seen":210.3,"rssi":-17.8},
#     {"hex":"a536dd","flight":"JTZ435  ","alt_baro":43000,"alt_geom":44575,"gs":349.1,"track":250.9,"baro_rate":0,"squawk":"3360","emergency":"none","category":"A1","nav_qnh":1013.6,"nav_altitude_mcp":43008,"nav_modes":["althold","tcas"],"lat":39.586533,"lon":-77.512247,"nic":9,"rc":75,"seen_pos":3.2,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":3,"mlat":[],"tisb":[],"messages":3335,"seen":0.6,"rssi":-14.9},
#     {"hex":"a708de","category":"A1","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":2044,"seen":210.5,"rssi":-17.1},
#     {"hex":"a114f4","flight":"AAL9834 ","category":"A3","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":183,"seen":0.5,"rssi":-16.9},
#     {"hex":"aa7718","flight":"SWA4914 ","alt_baro":38000,"alt_geom":39650,"gs":385.2,"track":222.1,"baro_rate":0,"squawk":"7024","emergency":"none","category":"A3","nav_qnh":1013.6,"nav_altitude_mcp":38016,"nav_heading":241.9,"lat":38.680435,"lon":-77.391994,"nic":8,"rc":186,"seen_pos":0.6,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":6736,"seen":0.3,"rssi":-3.0},
#     {"hex":"abe65a","category":"A3","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":3809,"seen":120.0,"rssi":-17.7},
#     {"hex":"ac7160","alt_baro":41000,"alt_geom":42525,"gs":505.5,"track":23.7,"geom_rate":0,"category":"A2","lat":40.048844,"lon":-76.894871,"nic":8,"rc":186,"seen_pos":33.1,"version":2,"nic_baro":1,"nac_p":10,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":6037,"seen":25.3,"rssi":-18.0},
#     {"hex":"a36f1d","category":"A2","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":2252,"seen":263.5,"rssi":-15.9},
#     {"hex":"ab2c04","flight":"AAL801  ","alt_baro":36000,"alt_geom":37675,"gs":397.4,"track":217.3,"baro_rate":0,"squawk":"1774","emergency":"none","category":"A3","nav_qnh":1013.6,"nav_altitude_mcp":36000,"nav_heading":234.8,"lat":38.343567,"lon":-77.839011,"nic":8,"rc":186,"seen_pos":0.2,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":8634,"seen":0.2,"rssi":-14.8},
#     {"hex":"a44166","category":"A3","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":3826,"seen":124.3,"rssi":-18.2},
#     {"hex":"ab30f0","category":"A3","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":363,"seen":171.9,"rssi":-17.0},
#     {"hex":"a4910c","category":"A1","nav_qnh":1024.0,"nav_altitude_mcp":17504,"nav_modes":["althold"],"version":2,"nic_baro":1,"nac_p":10,"sil":3,"sil_type":"perhour","mlat":[],"tisb":[],"messages":516,"seen":39.5,"rssi":-18.0},
#     {"hex":"a9fc34","category":"A3","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":5379,"seen":228.0,"rssi":-15.4},
#     {"hex":"acb21b","category":"A2","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":5788,"seen":75.9,"rssi":-18.0},
#     {"hex":"a1d93b","category":"A3","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":4799,"seen":99.0,"rssi":-17.8},
#     {"hex":"a3c3e0","alt_baro":34000,"alt_geom":35575,"gs":407.2,"track":233.2,"baro_rate":0,"category":"A4","version":2,"nac_v":1,"sil_type":"perhour","mlat":[],"tisb":[],"messages":10168,"seen":2.3,"rssi":-17.5},
#     {"hex":"a5d668","alt_baro":36000,"alt_geom":37700,"gs":400.6,"track":220.8,"baro_rate":0,"category":"A3","nav_qnh":1013.6,"nav_altitude_mcp":36000,"nav_heading":239.1,"version":2,"nic_baro":1,"nac_p":10,"nac_v":2,"sil":3,"sil_type":"perhour","mlat":[],"tisb":[],"messages":9800,"seen":0.6,"rssi":-17.0},
#     {"hex":"a7db41","flight":"EJA605  ","alt_baro":40000,"alt_geom":41525,"gs":337.6,"track":253.7,"baro_rate":0,"category":"A2","lat":39.823700,"lon":-78.989669,"nic":8,"rc":186,"seen_pos":21.4,"version":2,"nac_v":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":1176,"seen":19.9,"rssi":-16.3},
#     {"hex":"ad526c","flight":"AAL1802 ","alt_baro":35275,"alt_geom":36850,"gs":378.7,"track":253.4,"baro_rate":1024,"squawk":"1553","emergency":"none","category":"A3","nav_qnh":1013.6,"nav_altitude_mcp":36000,"nav_heading":263.0,"lat":39.031026,"lon":-78.897217,"nic":8,"rc":186,"seen_pos":7.8,"version":2,"nic_baro":1,"nac_p":9,"nac_v":1,"sil":3,"sil_type":"perhour","gva":2,"sda":2,"mlat":[],"tisb":[],"messages":6181,"seen":6.4,"rssi":-17.2},
#     {"hex":"a52844","category":"A2","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":10255,"seen":35.4,"rssi":-14.7},
#     {"hex":"a08f62","category":"A2","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":7563,"seen":173.8,"rssi":-18.0},
#     {"hex":"a03f1e","category":"A3","version":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":12370,"seen":114.3,"rssi":-17.6},
#     {"hex":"a1696b","alt_baro":36000,"alt_geom":37725,"gs":381.0,"track":238.0,"baro_rate":0,"category":"A3","version":2,"nac_v":2,"sil_type":"perhour","mlat":[],"tisb":[],"messages":11019,"seen":17.6,"rssi":-18.2}
#   ]
# }

# %%
import json
from pprint import pprint

# Open the JSON file and load its data into a Python object
#with open('filename.json', 'r') as file:
with open(pa_file, 'r') as fp:
    data = json.load(fp) # data is type dict
    print(f"type(data): {type(data)}")

# Pretty print the data
pprint(data)

# %%
import json
import pandas as pd

# Open the JSON file and load it
#with open('filename.json', 'r') as file:
with open(pa_file, 'r') as file:
    data = json.load(file)

# Convert the loaded JSON data to a pandas DataFrame
df = pd.DataFrame(data)

# Print the DataFrame
# Set Pandas options to display all rows and columns
pd.set_option('display.max_rows', None)      # Display all rows
pd.set_option('display.max_columns', None)   # Display all columns
#print(df)
#df.to_string()
df.head(1000)
# Out:
#              now    messages  \
# 0   1.728058e+09  2468159384
# 1   1.728058e+09  2468159384
# 2   1.728058e+09  2468159384
# 3   1.728058e+09  2468159384
# 4   1.728058e+09  2468159384
# 5   1.728058e+09  2468159384
# 6   1.728058e+09  2468159384
# 7   1.728058e+09  2468159384
# 8   1.728058e+09  2468159384
# 9   1.728058e+09  2468159384
# 10  1.728058e+09  2468159384
# 11  1.728058e+09  2468159384
# 12  1.728058e+09  2468159384
# 13  1.728058e+09  2468159384
# 14  1.728058e+09  2468159384
# 15  1.728058e+09  2468159384
# 16  1.728058e+09  2468159384
# 17  1.728058e+09  2468159384
# 18  1.728058e+09  2468159384
# 19  1.728058e+09  2468159384
# 20  1.728058e+09  2468159384
# 21  1.728058e+09  2468159384
# 22  1.728058e+09  2468159384
# 23  1.728058e+09  2468159384
# 24  1.728058e+09  2468159384
# 25  1.728058e+09  2468159384
# 26  1.728058e+09  2468159384
# 27  1.728058e+09  2468159384
# 28  1.728058e+09  2468159384
# 29  1.728058e+09  2468159384
# 30  1.728058e+09  2468159384
# 31  1.728058e+09  2468159384
# 32  1.728058e+09  2468159384
# 33  1.728058e+09  2468159384
# 34  1.728058e+09  2468159384
# 35  1.728058e+09  2468159384
# 36  1.728058e+09  2468159384
# 37  1.728058e+09  2468159384
# 38  1.728058e+09  2468159384
# 39  1.728058e+09  2468159384
# 40  1.728058e+09  2468159384
# 41  1.728058e+09  2468159384
# 42  1.728058e+09  2468159384
# 43  1.728058e+09  2468159384
# 44  1.728058e+09  2468159384
# 45  1.728058e+09  2468159384
# 46  1.728058e+09  2468159384
# 47  1.728058e+09  2468159384
# 48  1.728058e+09  2468159384
# 49  1.728058e+09  2468159384
# 50  1.728058e+09  2468159384
# 51  1.728058e+09  2468159384
# 52  1.728058e+09  2468159384
# 53  1.728058e+09  2468159384
# 54  1.728058e+09  2468159384
# 55  1.728058e+09  2468159384
# 56  1.728058e+09  2468159384
# 57  1.728058e+09  2468159384
# 58  1.728058e+09  2468159384
# 59  1.728058e+09  2468159384
# 60  1.728058e+09  2468159384
# 61  1.728058e+09  2468159384
# 62  1.728058e+09  2468159384
# 63  1.728058e+09  2468159384
# 64  1.728058e+09  2468159384
# 65  1.728058e+09  2468159384
# 66  1.728058e+09  2468159384
# 67  1.728058e+09  2468159384
# 68  1.728058e+09  2468159384
# 69  1.728058e+09  2468159384
# 70  1.728058e+09  2468159384
# 71  1.728058e+09  2468159384
# 72  1.728058e+09  2468159384
# 73  1.728058e+09  2468159384
# 74  1.728058e+09  2468159384
# 75  1.728058e+09  2468159384
# 76  1.728058e+09  2468159384
# 77  1.728058e+09  2468159384
# 78  1.728058e+09  2468159384
# 79  1.728058e+09  2468159384
# 80  1.728058e+09  2468159384
# 81  1.728058e+09  2468159384
# 82  1.728058e+09  2468159384
# 83  1.728058e+09  2468159384
# 84  1.728058e+09  2468159384
# 85  1.728058e+09  2468159384
# 86  1.728058e+09  2468159384
#
#                                              aircraft
# 0   {'hex': 'a9a541', 'alt_baro': 40000, 'version'...
# 1   {'hex': 'ac7e15', 'alt_baro': 30000, 'alt_geom...
# 2   {'hex': 'a44e1c', 'flight': 'DAL2411 ', 'alt_b...
# 3   {'hex': 'a6aac2', 'flight': 'JIA5180 ', 'alt_b...
# 4   {'hex': 'aa9f6f', 'alt_baro': 38000, 'alt_geom...
# 5   {'hex': 'a4ee36', 'alt_baro': 18500, 'squawk':...
# 6   {'hex': 'a7869b', 'alt_baro': 35000, 'alt_geom...
# 7   {'hex': 'a699b0', 'flight': 'VOS4326 ', 'alt_b...
# 8   {'hex': 'ae2fd3', 'alt_baro': 21750, 'alt_geom...
# 9   {'hex': 'a05470', 'flight': 'RPA4418 ', 'alt_b...
# 10  {'hex': 'abd230', 'flight': 'SWA3094 ', 'alt_b...
# 11  {'hex': 'abb8c4', 'flight': 'SWA3319 ', 'alt_b...
# 12  {'hex': 'abe82c', 'category': 'A3', 'version':...
# 13  {'hex': 'a01f73', 'flight': 'RPA4421 ', 'alt_b...
# 14  {'hex': 'a79821', 'flight': 'JBU698  ', 'alt_b...
# 15  {'hex': 'ac2f18', 'version': 0, 'sil_type': 'u...
# 16  {'hex': 'a0d72b', 'flight': 'AAL1379 ', 'alt_b...
# 17  {'hex': 'a03510', 'flight': 'EJA112  ', 'alt_b...
# 18  {'hex': 'a3298a', 'flight': 'JBU1310 ', 'alt_b...
# 19  {'hex': 'acd964', 'flight': 'AAL2332 ', 'alt_b...
# 20  {'hex': 'a4bfc7', 'flight': 'LXJ405  ', 'alt_b...
# 21  {'hex': 'ac28be', 'alt_baro': 34000, 'alt_geom...
# 22  {'hex': 'a6893c', 'flight': 'JIA5640 ', 'alt_b...
# 23  {'hex': 'a05bde', 'flight': 'RPA4373 ', 'alt_b...
# 24  {'hex': 'a7e630', 'flight': 'JIA5444 ', 'alt_b...
# 25  {'hex': 'aaffaa', 'flight': 'AAL1223 ', 'alt_b...
# 26  {'hex': 'a95635', 'flight': 'N700SY  ', 'alt_b...
# 27  {'hex': 'ab7b8c', 'flight': 'UAL674  ', 'alt_b...
# 28  {'hex': 'c05c86', 'alt_baro': 9750, 'alt_geom'...
# 29  {'hex': 'a45e8a', 'version': 0, 'sil_type': 'u...
# 30  {'hex': 'a53b26', 'category': 'A1', 'version':...
# 31  {'hex': 'a6152a', 'alt_baro': 33000, 'alt_geom...
# 32  {'hex': 'aaa58b', 'flight': 'UAL1044 ', 'alt_b...
# 33  {'hex': 'aaa326', 'flight': 'AAL731  ', 'alt_b...
# 34  {'hex': 'a897f4', 'flight': 'AAL1360 ', 'alt_b...
# 35  {'hex': 'ab0d76', 'alt_baro': 32000, 'alt_geom...
# 36  {'hex': 'a1623f', 'flight': 'N189BL  ', 'alt_b...
# 37  {'hex': 'aa763f', 'alt_baro': 23100, 'alt_geom...
# 38  {'hex': 'a1ea70', 'alt_baro': 19675, 'alt_geom...
# 39  {'hex': 'a677be', 'flight': 'JIA5578 ', 'alt_b...
# 40  {'hex': 'a87876', 'flight': 'GTI8839 ', 'alt_b...
# 41  {'hex': 'aa43c4', 'flight': 'RPA3528 ', 'alt_b...
# 42  {'hex': 'acb1f8', 'category': 'A2', 'version':...
# 43  {'hex': 'a2da7f', 'flight': 'PWR3    ', 'alt_b...
# 44  {'hex': 'a1bd4d', 'flight': 'AVL211  ', 'alt_b...
# 45  {'hex': 'a97310', 'alt_baro': 28125, 'category...
# 46  {'hex': 'adbaca', 'alt_baro': 32000, 'version'...
# 47  {'hex': 'a38cd2', 'alt_baro': 5750, 'alt_geom'...
# 48  {'hex': 'a4f1e5', 'flight': 'AAL655  ', 'alt_b...
# 49  {'hex': 'a071c8', 'flight': 'DAL2412 ', 'alt_b...
# 50  {'hex': 'a40312', 'flight': 'FFT3355 ', 'alt_b...
# 51  {'hex': 'aca6c9', 'flight': 'WMN914  ', 'alt_b...
# 52  {'hex': 'a2147c', 'gs': 507.4, 'track': 42.7, ...
# 53  {'hex': 'ad33e7', 'flight': 'N95SJ   ', 'alt_b...
# 54  {'hex': 'a2e516', 'flight': 'N286JJ  ', 'alt_b...
# 55  {'hex': 'ae695e', 'alt_baro': 16200, 'mlat': [...
# 56  {'hex': 'ac857b', 'category': 'A2', 'version':...
# 57  {'hex': 'a44b56', 'flight': 'DAL1514 ', 'alt_b...
# 58  {'hex': 'a2e045', 'gs': 506.7, 'track': 42.6, ...
# 59  {'hex': 'a19f29', 'category': 'A3', 'version':...
# 60  {'hex': 'ab6906', 'category': 'A1', 'version':...
# 61  {'hex': 'a4ef54', 'gs': 175.0, 'track': 233.1,...
# 62  {'hex': 'a64df2', 'category': 'A2', 'version':...
# 63  {'hex': 'ac98ac', 'category': 'A3', 'version':...
# 64  {'hex': 'a4105b', 'category': 'A3', 'version':...
# 65  {'hex': 'a536dd', 'flight': 'JTZ435  ', 'alt_b...
# 66  {'hex': 'a708de', 'category': 'A1', 'version':...
# 67  {'hex': 'a114f4', 'flight': 'AAL9834 ', 'categ...
# 68  {'hex': 'aa7718', 'flight': 'SWA4914 ', 'alt_b...
# 69  {'hex': 'abe65a', 'category': 'A3', 'version':...
# 70  {'hex': 'ac7160', 'alt_baro': 41000, 'alt_geom...
# 71  {'hex': 'a36f1d', 'category': 'A2', 'version':...
# 72  {'hex': 'ab2c04', 'flight': 'AAL801  ', 'alt_b...
# 73  {'hex': 'a44166', 'category': 'A3', 'version':...
# 74  {'hex': 'ab30f0', 'category': 'A3', 'version':...
# 75  {'hex': 'a4910c', 'category': 'A1', 'nav_qnh':...
# 76  {'hex': 'a9fc34', 'category': 'A3', 'version':...
# 77  {'hex': 'acb21b', 'category': 'A2', 'version':...
# 78  {'hex': 'a1d93b', 'category': 'A3', 'version':...
# 79  {'hex': 'a3c3e0', 'alt_baro': 34000, 'alt_geom...
# 80  {'hex': 'a5d668', 'alt_baro': 36000, 'alt_geom...
# 81  {'hex': 'a7db41', 'flight': 'EJA605  ', 'alt_b...
# 82  {'hex': 'ad526c', 'flight': 'AAL1802 ', 'alt_b...
# 83  {'hex': 'a52844', 'category': 'A2', 'version':...
# 84  {'hex': 'a08f62', 'category': 'A2', 'version':...
# 85  {'hex': 'a03f1e', 'category': 'A3', 'version':...
# 86  {'hex': 'a1696b', 'alt_baro': 36000, 'alt_geom...

# %%
# prompt: flatten this data frame

import pandas as pd

# Assuming 'df' is your DataFrame from the previous code

df_flattened = pd.json_normalize(data['aircraft']).sort_values(by='hex', ascending=True)


# print(df_flattened)
df_flattened.head(40)
# Out:
#        hex  alt_baro  version  nac_p  sil sil_type mlat tisb  messages   seen  \
# 13  a01f73    8750.0      2.0   10.0  3.0  perhour   []   []      1252    6.6
# 17  a03510    3100.0      2.0   10.0  3.0  perhour   []   []      1412    0.1
# 85  a03f1e       NaN      2.0    NaN  NaN  perhour   []   []     12370  114.3
# 9   a05470   34000.0      2.0   10.0  3.0  perhour   []   []       331    0.0
# 23  a05bde   13100.0      2.0   10.0  3.0  perhour   []   []       582    3.4
# 49  a071c8   38000.0      2.0   10.0  3.0  perhour   []   []      5175    0.2
# 84  a08f62       NaN      2.0    NaN  NaN  perhour   []   []      7563  173.8
# 16  a0d72b   35025.0      2.0    9.0  3.0  perhour   []   []      1340    0.8
# 67  a114f4       NaN      2.0    NaN  NaN  perhour   []   []       183    0.5
# 36  a1623f   30000.0      2.0   10.0  3.0  perhour   []   []      2049    1.4
# 86  a1696b   36000.0      2.0    NaN  NaN  perhour   []   []     11019   17.6
# 59  a19f29       NaN      2.0    NaN  NaN  perhour   []   []       667  138.0
# 44  a1bd4d    4750.0      2.0   10.0  3.0  perhour   []   []       973   17.6
# 78  a1d93b       NaN      2.0    NaN  NaN  perhour   []   []      4799   99.0
# 38  a1ea70   19675.0      2.0    NaN  NaN  perhour   []   []      1623    4.3
# 52  a2147c       NaN      2.0    NaN  NaN  perhour   []   []      1405   62.8
# 43  a2da7f    3775.0      2.0   10.0  3.0  perhour   []   []      3646    0.3
# 58  a2e045       NaN      2.0    NaN  NaN  perhour   []   []      2760   69.5
# 54  a2e516   25225.0      2.0   10.0  3.0  perhour   []   []      5443    0.2
# 18  a3298a   35000.0      2.0   10.0  3.0  perhour   []   []       194    0.1
# 71  a36f1d       NaN      2.0    NaN  NaN  perhour   []   []      2252  263.5
# 47  a38cd2    5750.0      2.0   10.0  3.0  perhour   []   []      1558    3.2
# 79  a3c3e0   34000.0      2.0    NaN  NaN  perhour   []   []     10168    2.3
# 50  a40312   34025.0      2.0   10.0  3.0  perhour   []   []      5146    0.0
# 64  a4105b       NaN      2.0    NaN  NaN  perhour   []   []      2105  210.3
# 73  a44166       NaN      2.0    NaN  NaN  perhour   []   []      3826  124.3
# 57  a44b56   34000.0      2.0    9.0  3.0  perhour   []   []      7547    0.1
# 2   a44e1c   34000.0      2.0   10.0  3.0  perhour   []   []       296   16.8
# 29  a45e8a       NaN      0.0    NaN  NaN  unknown   []   []        37  256.0
# 75  a4910c       NaN      2.0   10.0  3.0  perhour   []   []       516   39.5
# 20  a4bfc7   42975.0      2.0   10.0  3.0  perhour   []   []       581    8.9
# 5   a4ee36   18500.0      0.0    8.0  2.0  unknown   []   []        36    6.3
# 61  a4ef54       NaN      2.0    NaN  NaN  perhour   []   []      1734   29.4
# 48  a4f1e5   32000.0      2.0    9.0  3.0  perhour   []   []      1440    2.4
# 83  a52844       NaN      2.0    NaN  NaN  perhour   []   []     10255   35.4
# 65  a536dd   43000.0      2.0   10.0  3.0  perhour   []   []      3335    0.6
# 30  a53b26       NaN      2.0    NaN  NaN  perhour   []   []        20  248.4
# 80  a5d668   36000.0      2.0   10.0  3.0  perhour   []   []      9800    0.6
# 31  a6152a   33000.0      2.0    NaN  NaN  perhour   []   []      1317   11.4
# 62  a64df2       NaN      2.0    NaN  NaN  perhour   []   []      1032  210.0
#
#     rssi  alt_geom     gs  track  baro_rate  nav_qnh  nav_altitude_mcp  \
# 13 -14.2    9250.0  296.5   26.7      -64.0   1022.4            9024.0
# 17  -4.1    3350.0  274.1    1.5        NaN   1022.4            3008.0
# 85 -17.6       NaN    NaN    NaN        NaN      NaN               NaN
# 9  -11.7   35350.0  395.2  236.4       64.0   1013.6           34016.0
# 23 -13.5   13775.0  352.4   59.3     1856.0   1022.4           19008.0
# 49 -10.6   39675.0  376.9  225.1        NaN   1012.8           38016.0
# 84 -18.0       NaN    NaN    NaN        NaN      NaN               NaN
# 16 -17.4   36700.0  503.2   32.6        0.0   1013.6           35008.0
# 67 -16.9       NaN    NaN    NaN        NaN      NaN               NaN
# 36 -14.5   31325.0  263.0  242.9        0.0   1013.6           30016.0
# 86 -18.2   37725.0  381.0  238.0        0.0      NaN               NaN
# 59 -17.9       NaN    NaN    NaN        NaN      NaN               NaN
# 44 -16.6    4950.0  101.1  205.8     -128.0   1021.6            4992.0
# 78 -17.8       NaN    NaN    NaN        NaN      NaN               NaN
# 38 -16.2   20600.0  407.0  243.1     2240.0      NaN               NaN
# 52 -17.5       NaN  507.4   42.7      -64.0      NaN               NaN
# 43 -12.8    4025.0  234.3   51.8        NaN   1022.4            4000.0
# 58 -15.9       NaN  506.7   42.6    -2560.0      NaN               NaN
# 54 -12.4   26475.0  497.9   45.8        NaN   1013.6           24000.0
# 18 -13.7   36675.0  489.9   32.7        NaN   1012.8           35008.0
# 71 -15.9       NaN    NaN    NaN        NaN      NaN               NaN
# 47 -16.3    6100.0  232.6  183.9        0.0   1022.4            6016.0
# 79 -17.5   35575.0  407.2  233.2        0.0      NaN               NaN
# 50  -4.9   35600.0  407.3  225.0        0.0   1012.8           34016.0
# 64 -17.8       NaN    NaN    NaN        NaN      NaN               NaN
# 73 -18.2       NaN    NaN    NaN        NaN      NaN               NaN
# 57  -2.1   35625.0  408.7  225.0        0.0   1013.6           34016.0
# 2  -16.4   35450.0  401.0  236.4        0.0   1013.6           34016.0
# 29 -17.7       NaN    NaN    NaN        NaN      NaN               NaN
# 75 -18.0       NaN    NaN    NaN        NaN   1024.0           17504.0
# 20 -13.6   44600.0  382.9  220.8        NaN   1012.8           43008.0
# 5  -16.9       NaN    NaN    NaN        NaN      NaN               NaN
# 61 -16.1       NaN  175.0  233.1     1152.0      NaN               NaN
# 48  -9.3   33425.0  410.2  238.6        0.0   1012.8           32000.0
# 83 -14.7       NaN    NaN    NaN        NaN      NaN               NaN
# 65 -14.9   44575.0  349.1  250.9        0.0   1013.6           43008.0
# 30 -18.1       NaN    NaN    NaN        NaN      NaN               NaN
# 80 -17.0   37700.0  400.6  220.8        0.0   1013.6           36000.0
# 31 -18.8   34575.0  495.5   37.7        NaN      NaN               NaN
# 62 -14.8       NaN    NaN    NaN        NaN      NaN               NaN
#
#     nav_heading        lat        lon  nic     rc  seen_pos  nic_baro  nac_v  \
# 13          NaN  38.723373 -77.042820  8.0  186.0       8.7       1.0    2.0
# 17         12.0  38.947906 -77.350796  8.0  186.0       0.4       1.0    1.0
# 85          NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
# 9           NaN  39.798020 -76.395691  8.0  186.0       0.9       1.0    2.0
# 23          NaN  39.048250 -76.762146  8.0  186.0       5.1       1.0    2.0
# 49        242.6  39.034836 -76.943406  8.0  186.0       0.6       1.0    1.0
# 84          NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
# 16          NaN  38.313190 -76.506401  8.0  186.0      12.6       1.0    1.0
# 67          NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
# 36        254.5  39.310246 -78.038269  9.0   75.0       1.8       1.0    2.0
# 86          NaN        NaN        NaN  NaN    NaN       NaN       NaN    2.0
# 59          NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
# 44        208.1  38.965527 -77.731689  9.0   75.0      19.0       1.0    2.0
# 78          NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
# 38          NaN  38.486318 -77.808960  8.0  186.0       4.6       NaN    2.0
# 52          NaN        NaN        NaN  NaN    NaN       NaN       NaN    2.0
# 43         90.0  39.141495 -77.559715  8.0  186.0       5.6       1.0    1.0
# 58          NaN        NaN        NaN  NaN    NaN       NaN       NaN    1.0
# 54         56.2  39.273972 -76.293600  8.0  186.0       1.1       1.0    1.0
# 18         36.6  38.002396 -76.766091  8.0  186.0       0.2       1.0    1.0
# 71          NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
# 47          NaN  39.005701 -76.851562  8.0  186.0       3.7       1.0    2.0
# 79          NaN        NaN        NaN  NaN    NaN       NaN       NaN    1.0
# 50          NaN  38.857498 -77.171611  8.0  186.0       0.2       1.0    4.0
# 64          NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
# 73          NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
# 57          0.0  38.750381 -77.308462  8.0  186.0       0.1       1.0    1.0
# 2         248.9  39.903854 -76.189171  8.0  186.0      22.4       1.0    2.0
# 29          NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
# 75          NaN        NaN        NaN  NaN    NaN       NaN       1.0    NaN
# 20        240.5  39.356049 -76.698602  8.0  186.0       9.8       1.0    1.0
# 5           NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
# 61          NaN        NaN        NaN  NaN    NaN       NaN       NaN    2.0
# 48          NaN  39.440173 -77.733337  8.0  186.0       2.8       1.0    1.0
# 83          NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
# 65          NaN  39.586533 -77.512247  9.0   75.0       3.2       1.0    2.0
# 30          NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
# 80        239.1        NaN        NaN  NaN    NaN       NaN       1.0    2.0
# 31          NaN  38.508058 -76.203186  8.0  186.0      67.4       NaN    1.0
# 62          NaN        NaN        NaN  NaN    NaN       NaN       NaN    NaN
#
#     gva  sda    flight squawk emergency category  geom_rate  nav_altitude_fms  \
# 13  2.0  2.0  RPA4421    4607      none       A3        NaN               NaN
# 17  2.0  2.0  EJA112     0570      none       A3     -896.0               NaN
# 85  NaN  NaN       NaN    NaN       NaN       A3        NaN               NaN
# 9   2.0  2.0  RPA4418     NaN       NaN       A3        NaN               NaN
# 23  2.0  2.0  RPA4373    5627      none       A3        NaN               NaN
# 49  2.0  2.0  DAL2412    3350      none       A3        0.0               NaN
# 84  NaN  NaN       NaN    NaN       NaN       A2        NaN               NaN
# 16  2.0  2.0  AAL1379    6051      none       A3        NaN               NaN
# 67  NaN  NaN  AAL9834     NaN       NaN       A3        NaN               NaN
# 36  2.0  2.0  N189BL     2762      none       A1        NaN               NaN
# 86  NaN  NaN       NaN    NaN       NaN       A3        NaN               NaN
# 59  NaN  NaN       NaN    NaN       NaN       A3        NaN               NaN
# 44  2.0  2.0  AVL211     4642      none       A1        NaN               NaN
# 78  NaN  NaN       NaN    NaN       NaN       A3        NaN               NaN
# 38  NaN  NaN       NaN    NaN       NaN       A3        NaN               NaN
# 52  NaN  NaN       NaN    NaN       NaN       A3        NaN               NaN
# 43  2.0  2.0  PWR3       7324      none       A2     -128.0               NaN
# 58  NaN  NaN       NaN    NaN       NaN       A3        NaN               NaN
# 54  2.0  2.0  N286JJ     3443      none       A2    -2560.0               NaN
# 18  2.0  2.0  JBU1310    0745       NaN       A3      -64.0               NaN
# 71  NaN  NaN       NaN    NaN       NaN       A2        NaN               NaN
# 47  2.0  2.0       NaN    NaN       NaN       A3        NaN               NaN
# 79  NaN  NaN       NaN    NaN       NaN       A4        NaN               NaN
# 50  2.0  3.0  FFT3355    2673      none       A3        NaN               NaN
# 64  NaN  NaN       NaN    NaN       NaN       A3        NaN               NaN
# 73  NaN  NaN       NaN    NaN       NaN       A3        NaN               NaN
# 57  2.0  2.0  DAL1514    1767      none       A3        NaN               NaN
# 2   2.0  2.0  DAL2411    3054      none       A3        NaN               NaN
# 29  NaN  NaN       NaN    NaN       NaN      NaN        NaN               NaN
# 75  NaN  NaN       NaN    NaN       NaN       A1        NaN               NaN
# 20  2.0  2.0  LXJ405     1136      none       A2        0.0               NaN
# 5   NaN  NaN       NaN   2641      none      NaN        NaN               NaN
# 61  NaN  NaN       NaN    NaN       NaN       A1        NaN               NaN
# 48  2.0  3.0  AAL655     1147      none       A3        NaN               NaN
# 83  NaN  NaN       NaN    NaN       NaN       A2        NaN               NaN
# 65  2.0  3.0  JTZ435     3360      none       A1        NaN               NaN
# 30  NaN  NaN       NaN    NaN       NaN       A1        NaN               NaN
# 80  NaN  NaN       NaN    NaN       NaN       A3        NaN               NaN
# 31  NaN  NaN       NaN    NaN       NaN       A3        0.0               NaN
# 62  NaN  NaN       NaN    NaN       NaN       A2        NaN               NaN
#
#                      nav_modes
# 13  [autopilot, althold, tcas]
# 17                         NaN
# 85                         NaN
# 9      [autopilot, vnav, tcas]
# 23     [autopilot, vnav, tcas]
# 49                         NaN
# 84                         NaN
# 16                         NaN
# 67                         NaN
# 36  [autopilot, althold, lnav]
# 86                         NaN
# 59                         NaN
# 44                         NaN
# 78                         NaN
# 38                         NaN
# 52                         NaN
# 43                         NaN
# 58                         NaN
# 54                         NaN
# 18                         NaN
# 71                         NaN
# 47  [autopilot, althold, tcas]
# 79                         NaN
# 50                         NaN
# 64                         NaN
# 73                         NaN
# 57                         NaN
# 2                          NaN
# 29                         NaN
# 75                   [althold]
# 20                         NaN
# 5                          NaN
# 61                         NaN
# 48                         NaN
# 83                         NaN
# 65             [althold, tcas]
# 30                         NaN
# 80                         NaN
# 31                         NaN
# 62                         NaN

# %%
data['aircraft']
# Out:
# [{'hex': 'a9a541',
#   'alt_baro': 40000,
#   'version': 0,
#   'nac_p': 8,
#   'sil': 2,
#   'sil_type': 'unknown',
#   'mlat': [],
#   'tisb': [],
#   'messages': 11,
#   'seen': 6.3,
#   'rssi': -17.5},
#  {'hex': 'ac7e15',
#   'alt_baro': 30000,
#   'alt_geom': 31375,
#   'gs': 405.9,
#   'track': 229.8,
#   'baro_rate': 0,
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 30016,
#   'nav_heading': 240.5,
#   'lat': 39.522291,
#   'lon': -76.296387,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 6.4,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 167,
#   'seen': 0.6,
#   'rssi': -13.8},
#  {'hex': 'a44e1c',
#   'flight': 'DAL2411 ',
#   'alt_baro': 34000,
#   'alt_geom': 35450,
#   'gs': 401.0,
#   'track': 236.4,
#   'baro_rate': 0,
#   'squawk': '3054',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 34016,
#   'nav_heading': 248.9,
#   'lat': 39.903854,
#   'lon': -76.189171,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 22.4,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 296,
#   'seen': 16.8,
#   'rssi': -16.4},
#  {'hex': 'a6aac2',
#   'flight': 'JIA5180 ',
#   'alt_baro': 34000,
#   'alt_geom': 35675,
#   'gs': 503.3,
#   'track': 32.2,
#   'geom_rate': 0,
#   'squawk': '2257',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 34016,
#   'nav_heading': 33.0,
#   'lat': 38.113358,
#   'lon': -76.661137,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 1.5,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 648,
#   'seen': 1.3,
#   'rssi': -16.5},
#  {'hex': 'aa9f6f',
#   'alt_baro': 38000,
#   'alt_geom': 39600,
#   'gs': 416.4,
#   'track': 230.7,
#   'baro_rate': 0,
#   'squawk': '2420',
#   'emergency': 'none',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 38016,
#   'nav_heading': 248.2,
#   'lat': 39.599808,
#   'lon': -76.177109,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.4,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 179,
#   'seen': 0.4,
#   'rssi': -12.8},
#  {'hex': 'a4ee36',
#   'alt_baro': 18500,
#   'squawk': '2641',
#   'emergency': 'none',
#   'version': 0,
#   'nac_p': 8,
#   'sil': 2,
#   'sil_type': 'unknown',
#   'mlat': [],
#   'tisb': [],
#   'messages': 36,
#   'seen': 6.3,
#   'rssi': -16.9},
#  {'hex': 'a7869b',
#   'alt_baro': 35000,
#   'alt_geom': 36625,
#   'gs': 455.1,
#   'track': 347.3,
#   'baro_rate': 0,
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 35008,
#   'lat': 38.6371,
#   'lon': -78.142334,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 1.1,
#   'version': 0,
#   'nic_baro': 1,
#   'nac_p': 8,
#   'nac_v': 1,
#   'sil': 2,
#   'sil_type': 'unknown',
#   'mlat': [],
#   'tisb': [],
#   'messages': 61,
#   'seen': 1.1,
#   'rssi': -16.4},
#  {'hex': 'a699b0',
#   'flight': 'VOS4326 ',
#   'alt_baro': 3775,
#   'alt_geom': 4075,
#   'gs': 251.1,
#   'track': 1.6,
#   'baro_rate': 0,
#   'squawk': '2707',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1022.4,
#   'nav_altitude_mcp': 4000,
#   'lat': 38.82724,
#   'lon': -77.355214,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.0,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 346,
#   'seen': 0.0,
#   'rssi': -9.2},
#  {'hex': 'ae2fd3',
#   'alt_baro': 21750,
#   'alt_geom': 22850,
#   'gs': 182.9,
#   'track': 218.6,
#   'baro_rate': 0,
#   'nav_qnh': 1021.6,
#   'nav_altitude_fms': 21888,
#   'nav_heading': 0.0,
#   'lat': 38.477799,
#   'lon': -75.980286,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 5.2,
#   'version': 0,
#   'nic_baro': 1,
#   'nac_p': 8,
#   'nac_v': 4,
#   'sil': 2,
#   'sil_type': 'unknown',
#   'mlat': [],
#   'tisb': [],
#   'messages': 63,
#   'seen': 4.6,
#   'rssi': -15.3},
#  {'hex': 'a05470',
#   'flight': 'RPA4418 ',
#   'alt_baro': 34000,
#   'alt_geom': 35350,
#   'gs': 395.2,
#   'track': 236.4,
#   'baro_rate': 64,
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 34016,
#   'nav_modes': ['autopilot', 'vnav', 'tcas'],
#   'lat': 39.79802,
#   'lon': -76.395691,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.9,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 331,
#   'seen': 0.0,
#   'rssi': -11.7},
#  {'hex': 'abd230',
#   'flight': 'SWA3094 ',
#   'alt_baro': 12725,
#   'alt_geom': 13275,
#   'gs': 365.1,
#   'track': 271.4,
#   'baro_rate': 3392,
#   'squawk': '6236',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1022.4,
#   'nav_altitude_mcp': 23008,
#   'nav_heading': 340.3,
#   'lat': 39.221191,
#   'lon': -77.043059,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 1.9,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 706,
#   'seen': 0.4,
#   'rssi': -8.6},
#  {'hex': 'abb8c4',
#   'flight': 'SWA3319 ',
#   'alt_baro': 24425,
#   'alt_geom': 25675,
#   'gs': 458.9,
#   'track': 72.6,
#   'baro_rate': -2112,
#   'squawk': '6775',
#   'emergency': 'none',
#   'category': 'A3',
#   'lat': 38.551849,
#   'lon': -78.225224,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 1.8,
#   'version': 2,
#   'nac_v': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 60,
#   'seen': 1.3,
#   'rssi': -16.5},
#  {'hex': 'abe82c',
#   'category': 'A3',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 111,
#   'seen': 147.2,
#   'rssi': -15.2},
#  {'hex': 'a01f73',
#   'flight': 'RPA4421 ',
#   'alt_baro': 8750,
#   'alt_geom': 9250,
#   'gs': 296.5,
#   'track': 26.7,
#   'baro_rate': -64,
#   'squawk': '4607',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1022.4,
#   'nav_altitude_mcp': 9024,
#   'nav_modes': ['autopilot', 'althold', 'tcas'],
#   'lat': 38.723373,
#   'lon': -77.04282,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 8.7,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 1252,
#   'seen': 6.6,
#   'rssi': -14.2},
#  {'hex': 'a79821',
#   'flight': 'JBU698  ',
#   'alt_baro': 36175,
#   'alt_geom': 37950,
#   'gs': 485.2,
#   'track': 26.8,
#   'baro_rate': -960,
#   'squawk': '0722',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 31008,
#   'nav_heading': 0.0,
#   'lat': 38.198625,
#   'lon': -76.473979,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 1.2,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 1189,
#   'seen': 0.3,
#   'rssi': -16.0},
#  {'hex': 'ac2f18',
#   'version': 0,
#   'sil_type': 'unknown',
#   'mlat': [],
#   'tisb': [],
#   'messages': 21,
#   'seen': 125.9,
#   'rssi': -18.0},
#  {'hex': 'a0d72b',
#   'flight': 'AAL1379 ',
#   'alt_baro': 35025,
#   'alt_geom': 36700,
#   'gs': 503.2,
#   'track': 32.6,
#   'baro_rate': 0,
#   'squawk': '6051',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 35008,
#   'lat': 38.31319,
#   'lon': -76.506401,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 12.6,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 1340,
#   'seen': 0.8,
#   'rssi': -17.4},
#  {'hex': 'a03510',
#   'flight': 'EJA112  ',
#   'alt_baro': 3100,
#   'alt_geom': 3350,
#   'gs': 274.1,
#   'track': 1.5,
#   'geom_rate': -896,
#   'squawk': '0570',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1022.4,
#   'nav_altitude_mcp': 3008,
#   'nav_heading': 12.0,
#   'lat': 38.947906,
#   'lon': -77.350796,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.4,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 1412,
#   'seen': 0.1,
#   'rssi': -4.1},
#  {'hex': 'a3298a',
#   'flight': 'JBU1310 ',
#   'alt_baro': 35000,
#   'alt_geom': 36675,
#   'gs': 489.9,
#   'track': 32.7,
#   'geom_rate': -64,
#   'squawk': '0745',
#   'category': 'A3',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 35008,
#   'nav_heading': 36.6,
#   'lat': 38.002396,
#   'lon': -76.766091,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.2,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 194,
#   'seen': 0.1,
#   'rssi': -13.7},
#  {'hex': 'acd964',
#   'flight': 'AAL2332 ',
#   'alt_baro': 27775,
#   'alt_geom': 29125,
#   'gs': 415.1,
#   'track': 225.3,
#   'baro_rate': 1408,
#   'squawk': '1102',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 32000,
#   'nav_heading': 237.0,
#   'lat': 39.22431,
#   'lon': -76.698486,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.3,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 870,
#   'seen': 0.2,
#   'rssi': -9.3},
#  {'hex': 'a4bfc7',
#   'flight': 'LXJ405  ',
#   'alt_baro': 42975,
#   'alt_geom': 44600,
#   'gs': 382.9,
#   'track': 220.8,
#   'geom_rate': 0,
#   'squawk': '1136',
#   'emergency': 'none',
#   'category': 'A2',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 43008,
#   'nav_heading': 240.5,
#   'lat': 39.356049,
#   'lon': -76.698602,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 9.8,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 581,
#   'seen': 8.9,
#   'rssi': -13.6},
#  {'hex': 'ac28be',
#   'alt_baro': 34000,
#   'alt_geom': 35400,
#   'gs': 401.0,
#   'track': 250.9,
#   'baro_rate': 0,
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 34016,
#   'nav_heading': 263.0,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 107,
#   'seen': 7.1,
#   'rssi': -17.6},
#  {'hex': 'a6893c',
#   'flight': 'JIA5640 ',
#   'alt_baro': 12525,
#   'alt_geom': 13150,
#   'gs': 349.4,
#   'track': 335.1,
#   'geom_rate': 2048,
#   'squawk': '3630',
#   'emergency': 'none',
#   'category': 'A2',
#   'nav_qnh': 1022.4,
#   'nav_altitude_mcp': 12992,
#   'lat': 38.88002,
#   'lon': -77.32321,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.2,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 2774,
#   'seen': 0.1,
#   'rssi': -2.9},
#  {'hex': 'a05bde',
#   'flight': 'RPA4373 ',
#   'alt_baro': 13100,
#   'alt_geom': 13775,
#   'gs': 352.4,
#   'track': 59.3,
#   'baro_rate': 1856,
#   'squawk': '5627',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1022.4,
#   'nav_altitude_mcp': 19008,
#   'nav_modes': ['autopilot', 'vnav', 'tcas'],
#   'lat': 39.04825,
#   'lon': -76.762146,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 5.1,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 582,
#   'seen': 3.4,
#   'rssi': -13.5},
#  {'hex': 'a7e630',
#   'flight': 'JIA5444 ',
#   'alt_baro': 26125,
#   'alt_geom': 27375,
#   'gs': 397.7,
#   'track': 219.7,
#   'geom_rate': 1216,
#   'squawk': '1105',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 34016,
#   'nav_heading': 232.0,
#   'lat': 39.454239,
#   'lon': -77.021086,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 1.6,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 1452,
#   'seen': 0.1,
#   'rssi': -9.7},
#  {'hex': 'aaffaa',
#   'flight': 'AAL1223 ',
#   'alt_baro': 18575,
#   'alt_geom': 19400,
#   'gs': 384.1,
#   'track': 67.2,
#   'baro_rate': 2432,
#   'category': 'A3',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 20992,
#   'lat': 38.967621,
#   'lon': -76.543701,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 44.4,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 407,
#   'seen': 0.1,
#   'rssi': -16.2},
#  {'hex': 'a95635',
#   'flight': 'N700SY  ',
#   'alt_baro': 6750,
#   'alt_geom': 7175,
#   'gs': 238.4,
#   'track': 108.6,
#   'baro_rate': 0,
#   'squawk': '4725',
#   'emergency': 'none',
#   'category': 'A1',
#   'nav_qnh': 1022.4,
#   'nav_altitude_mcp': 7008,
#   'lat': 39.347907,
#   'lon': -76.968079,
#   'nic': 9,
#   'rc': 75,
#   'seen_pos': 0.6,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 566,
#   'seen': 0.4,
#   'rssi': -15.3},
#  {'hex': 'ab7b8c',
#   'flight': 'UAL674  ',
#   'alt_baro': 35025,
#   'alt_geom': 36650,
#   'gs': 508.8,
#   'track': 37.3,
#   'baro_rate': -64,
#   'squawk': '3606',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 27008,
#   'lat': 38.582308,
#   'lon': -76.808533,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 5.1,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 1549,
#   'seen': 0.2,
#   'rssi': -12.2},
#  {'hex': 'c05c86',
#   'alt_baro': 9750,
#   'alt_geom': 10225,
#   'gs': 245.2,
#   'track': 151.8,
#   'geom_rate': 0,
#   'squawk': '6246',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1022.4,
#   'nav_altitude_mcp': 10016,
#   'nav_heading': 168.8,
#   'lat': 39.228287,
#   'lon': -76.701647,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 2.7,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 831,
#   'seen': 0.8,
#   'rssi': -15.1},
#  {'hex': 'a45e8a',
#   'version': 0,
#   'sil_type': 'unknown',
#   'mlat': [],
#   'tisb': [],
#   'messages': 37,
#   'seen': 256.0,
#   'rssi': -17.7},
#  {'hex': 'a53b26',
#   'category': 'A1',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 20,
#   'seen': 248.4,
#   'rssi': -18.1},
#  {'hex': 'a6152a',
#   'alt_baro': 33000,
#   'alt_geom': 34575,
#   'gs': 495.5,
#   'track': 37.7,
#   'geom_rate': 0,
#   'category': 'A3',
#   'lat': 38.508058,
#   'lon': -76.203186,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 67.4,
#   'version': 2,
#   'nac_v': 1,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 1317,
#   'seen': 11.4,
#   'rssi': -18.8},
#  {'hex': 'aaa58b',
#   'flight': 'UAL1044 ',
#   'alt_baro': 10750,
#   'alt_geom': 11275,
#   'gs': 286.3,
#   'track': 177.6,
#   'baro_rate': 0,
#   'squawk': '3263',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1022.4,
#   'nav_altitude_mcp': 11008,
#   'nav_heading': 189.8,
#   'lat': 38.898056,
#   'lon': -77.814849,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 2.4,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 1303,
#   'seen': 0.1,
#   'rssi': -11.5},
#  {'hex': 'aaa326',
#   'flight': 'AAL731  ',
#   'alt_baro': 38000,
#   'alt_geom': 39625,
#   'gs': 408.0,
#   'track': 225.3,
#   'baro_rate': 0,
#   'squawk': '2411',
#   'emergency': 'none',
#   'category': 'A5',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 38016,
#   'nav_heading': 241.9,
#   'lat': 39.255753,
#   'lon': -76.657702,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.2,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 3118,
#   'seen': 0.1,
#   'rssi': -4.8},
#  {'hex': 'a897f4',
#   'flight': 'AAL1360 ',
#   'alt_baro': 36000,
#   'alt_geom': 37600,
#   'gs': 407.9,
#   'track': 206.2,
#   'baro_rate': 0,
#   'squawk': '2730',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 36000,
#   'lat': 39.356146,
#   'lon': -77.319885,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 5.6,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 1746,
#   'seen': 3.7,
#   'rssi': -10.6},
#  {'hex': 'ab0d76',
#   'alt_baro': 32000,
#   'alt_geom': 33350,
#   'gs': 412.0,
#   'track': 270.1,
#   'baro_rate': 0,
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 32000,
#   'nav_heading': 350.9,
#   'lat': 40.071794,
#   'lon': -76.869028,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 46.4,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 1026,
#   'seen': 0.6,
#   'rssi': -18.0},
#  {'hex': 'a1623f',
#   'flight': 'N189BL  ',
#   'alt_baro': 30000,
#   'alt_geom': 31325,
#   'gs': 263.0,
#   'track': 242.9,
#   'baro_rate': 0,
#   'squawk': '2762',
#   'emergency': 'none',
#   'category': 'A1',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 30016,
#   'nav_heading': 254.5,
#   'nav_modes': ['autopilot', 'althold', 'lnav'],
#   'lat': 39.310246,
#   'lon': -78.038269,
#   'nic': 9,
#   'rc': 75,
#   'seen_pos': 1.8,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 2049,
#   'seen': 1.4,
#   'rssi': -14.5},
#  {'hex': 'aa763f',
#   'alt_baro': 23100,
#   'alt_geom': 24350,
#   'gs': 447.5,
#   'track': 75.4,
#   'baro_rate': -1856,
#   'squawk': '5613',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 15008,
#   'lat': 38.719638,
#   'lon': -76.680847,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 24.5,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 2783,
#   'seen': 7.3,
#   'rssi': -15.9},
#  {'hex': 'a1ea70',
#   'alt_baro': 19675,
#   'alt_geom': 20600,
#   'gs': 407.0,
#   'track': 243.1,
#   'baro_rate': 2240,
#   'category': 'A3',
#   'lat': 38.486318,
#   'lon': -77.80896,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 4.6,
#   'version': 2,
#   'nac_v': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 1623,
#   'seen': 4.3,
#   'rssi': -16.2},
#  {'hex': 'a677be',
#   'flight': 'JIA5578 ',
#   'alt_baro': 28275,
#   'alt_geom': 29600,
#   'gs': 392.7,
#   'track': 238.5,
#   'geom_rate': 832,
#   'squawk': '3341',
#   'emergency': 'none',
#   'category': 'A2',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 34016,
#   'lat': 39.667674,
#   'lon': -77.260193,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 10.8,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 921,
#   'seen': 2.7,
#   'rssi': -16.5},
#  {'hex': 'a87876',
#   'flight': 'GTI8839 ',
#   'alt_baro': 3750,
#   'category': 'A5',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 99,
#   'seen': 47.9,
#   'rssi': -15.9},
#  {'hex': 'aa43c4',
#   'flight': 'RPA3528 ',
#   'alt_baro': 30975,
#   'alt_geom': 32325,
#   'gs': 495.9,
#   'track': 49.7,
#   'baro_rate': -832,
#   'squawk': '2171',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 27008,
#   'nav_modes': ['autopilot', 'vnav', 'tcas'],
#   'lat': 38.85301,
#   'lon': -76.723083,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 1.9,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 3743,
#   'seen': 1.3,
#   'rssi': -13.7},
#  {'hex': 'acb1f8',
#   'category': 'A2',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 2045,
#   'seen': 166.9,
#   'rssi': -14.6},
#  {'hex': 'a2da7f',
#   'flight': 'PWR3    ',
#   'alt_baro': 3775,
#   'alt_geom': 4025,
#   'gs': 234.3,
#   'track': 51.8,
#   'geom_rate': -128,
#   'squawk': '7324',
#   'emergency': 'none',
#   'category': 'A2',
#   'nav_qnh': 1022.4,
#   'nav_altitude_mcp': 4000,
#   'nav_heading': 90.0,
#   'lat': 39.141495,
#   'lon': -77.559715,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 5.6,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 3646,
#   'seen': 0.3,
#   'rssi': -12.8},
#  {'hex': 'a1bd4d',
#   'flight': 'AVL211  ',
#   'alt_baro': 4750,
#   'alt_geom': 4950,
#   'gs': 101.1,
#   'track': 205.8,
#   'baro_rate': -128,
#   'squawk': '4642',
#   'emergency': 'none',
#   'category': 'A1',
#   'nav_qnh': 1021.6,
#   'nav_altitude_mcp': 4992,
#   'nav_heading': 208.1,
#   'lat': 38.965527,
#   'lon': -77.731689,
#   'nic': 9,
#   'rc': 75,
#   'seen_pos': 19.0,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 973,
#   'seen': 17.6,
#   'rssi': -16.6},
#  {'hex': 'a97310',
#   'alt_baro': 28125,
#   'category': 'A3',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 1962,
#   'seen': 14.7,
#   'rssi': -16.5},
#  {'hex': 'adbaca',
#   'alt_baro': 32000,
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 126,
#   'seen': 11.8,
#   'rssi': -18.7},
#  {'hex': 'a38cd2',
#   'alt_baro': 5750,
#   'alt_geom': 6100,
#   'gs': 232.6,
#   'track': 183.9,
#   'baro_rate': 0,
#   'category': 'A3',
#   'nav_qnh': 1022.4,
#   'nav_altitude_mcp': 6016,
#   'nav_modes': ['autopilot', 'althold', 'tcas'],
#   'lat': 39.005701,
#   'lon': -76.851562,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 3.7,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 1558,
#   'seen': 3.2,
#   'rssi': -16.3},
#  {'hex': 'a4f1e5',
#   'flight': 'AAL655  ',
#   'alt_baro': 32000,
#   'alt_geom': 33425,
#   'gs': 410.2,
#   'track': 238.6,
#   'baro_rate': 0,
#   'squawk': '1147',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 32000,
#   'lat': 39.440173,
#   'lon': -77.733337,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 2.8,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 3,
#   'mlat': [],
#   'tisb': [],
#   'messages': 1440,
#   'seen': 2.4,
#   'rssi': -9.3},
#  {'hex': 'a071c8',
#   'flight': 'DAL2412 ',
#   'alt_baro': 38000,
#   'alt_geom': 39675,
#   'gs': 376.9,
#   'track': 225.1,
#   'geom_rate': 0,
#   'squawk': '3350',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 38016,
#   'nav_heading': 242.6,
#   'lat': 39.034836,
#   'lon': -76.943406,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.6,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 5175,
#   'seen': 0.2,
#   'rssi': -10.6},
#  {'hex': 'a40312',
#   'flight': 'FFT3355 ',
#   'alt_baro': 34025,
#   'alt_geom': 35600,
#   'gs': 407.3,
#   'track': 225.0,
#   'baro_rate': 0,
#   'squawk': '2673',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 34016,
#   'lat': 38.857498,
#   'lon': -77.171611,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.2,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 4,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 3,
#   'mlat': [],
#   'tisb': [],
#   'messages': 5146,
#   'seen': 0.0,
#   'rssi': -4.9},
#  {'hex': 'aca6c9',
#   'flight': 'WMN914  ',
#   'alt_baro': 32625,
#   'alt_geom': 34100,
#   'gs': 381.9,
#   'track': 253.4,
#   'geom_rate': 2176,
#   'squawk': '7012',
#   'emergency': 'none',
#   'category': 'A2',
#   'nav_qnh': 1012.8,
#   'nav_altitude_mcp': 34016,
#   'nav_heading': 265.1,
#   'lat': 38.901331,
#   'lon': -78.004761,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.3,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 6220,
#   'seen': 0.1,
#   'rssi': -10.4},
#  {'hex': 'a2147c',
#   'gs': 507.4,
#   'track': 42.7,
#   'baro_rate': -64,
#   'category': 'A3',
#   'version': 2,
#   'nac_v': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 1405,
#   'seen': 62.8,
#   'rssi': -17.5},
#  {'hex': 'ad33e7',
#   'flight': 'N95SJ   ',
#   'alt_baro': 1775,
#   'alt_geom': 1925,
#   'gs': 169.2,
#   'track': 182.7,
#   'baro_rate': 64,
#   'squawk': '4177',
#   'emergency': 'none',
#   'category': 'A2',
#   'nav_qnh': 1022.4,
#   'nav_altitude_mcp': 2016,
#   'nav_modes': ['autopilot', 'althold', 'tcas'],
#   'lat': 39.094711,
#   'lon': -77.457196,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 1.5,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 3346,
#   'seen': 0.7,
#   'rssi': -10.9},
#  {'hex': 'a2e516',
#   'flight': 'N286JJ  ',
#   'alt_baro': 25225,
#   'alt_geom': 26475,
#   'gs': 497.9,
#   'track': 45.8,
#   'geom_rate': -2560,
#   'squawk': '3443',
#   'emergency': 'none',
#   'category': 'A2',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 24000,
#   'nav_heading': 56.2,
#   'lat': 39.273972,
#   'lon': -76.2936,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 1.1,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 5443,
#   'seen': 0.2,
#   'rssi': -12.4},
#  {'hex': 'ae695e',
#   'alt_baro': 16200,
#   'mlat': [],
#   'tisb': [],
#   'messages': 3954,
#   'seen': 0.1,
#   'rssi': -13.7},
#  {'hex': 'ac857b',
#   'category': 'A2',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 2519,
#   'seen': 205.6,
#   'rssi': -17.4},
#  {'hex': 'a44b56',
#   'flight': 'DAL1514 ',
#   'alt_baro': 34000,
#   'alt_geom': 35625,
#   'gs': 408.7,
#   'track': 225.0,
#   'baro_rate': 0,
#   'squawk': '1767',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 34016,
#   'nav_heading': 0.0,
#   'lat': 38.750381,
#   'lon': -77.308462,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.1,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 7547,
#   'seen': 0.1,
#   'rssi': -2.1},
#  {'hex': 'a2e045',
#   'gs': 506.7,
#   'track': 42.6,
#   'baro_rate': -2560,
#   'category': 'A3',
#   'version': 2,
#   'nac_v': 1,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 2760,
#   'seen': 69.5,
#   'rssi': -15.9},
#  {'hex': 'a19f29',
#   'category': 'A3',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 667,
#   'seen': 138.0,
#   'rssi': -17.9},
#  {'hex': 'ab6906',
#   'category': 'A1',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 5811,
#   'seen': 108.9,
#   'rssi': -14.4},
#  {'hex': 'a4ef54',
#   'gs': 175.0,
#   'track': 233.1,
#   'baro_rate': 1152,
#   'category': 'A1',
#   'version': 2,
#   'nac_v': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 1734,
#   'seen': 29.4,
#   'rssi': -16.1},
#  {'hex': 'a64df2',
#   'category': 'A2',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 1032,
#   'seen': 210.0,
#   'rssi': -14.8},
#  {'hex': 'ac98ac',
#   'category': 'A3',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 2656,
#   'seen': 177.1,
#   'rssi': -13.9},
#  {'hex': 'a4105b',
#   'category': 'A3',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 2105,
#   'seen': 210.3,
#   'rssi': -17.8},
#  {'hex': 'a536dd',
#   'flight': 'JTZ435  ',
#   'alt_baro': 43000,
#   'alt_geom': 44575,
#   'gs': 349.1,
#   'track': 250.9,
#   'baro_rate': 0,
#   'squawk': '3360',
#   'emergency': 'none',
#   'category': 'A1',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 43008,
#   'nav_modes': ['althold', 'tcas'],
#   'lat': 39.586533,
#   'lon': -77.512247,
#   'nic': 9,
#   'rc': 75,
#   'seen_pos': 3.2,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 3,
#   'mlat': [],
#   'tisb': [],
#   'messages': 3335,
#   'seen': 0.6,
#   'rssi': -14.9},
#  {'hex': 'a708de',
#   'category': 'A1',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 2044,
#   'seen': 210.5,
#   'rssi': -17.1},
#  {'hex': 'a114f4',
#   'flight': 'AAL9834 ',
#   'category': 'A3',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 183,
#   'seen': 0.5,
#   'rssi': -16.9},
#  {'hex': 'aa7718',
#   'flight': 'SWA4914 ',
#   'alt_baro': 38000,
#   'alt_geom': 39650,
#   'gs': 385.2,
#   'track': 222.1,
#   'baro_rate': 0,
#   'squawk': '7024',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 38016,
#   'nav_heading': 241.9,
#   'lat': 38.680435,
#   'lon': -77.391994,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.6,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 6736,
#   'seen': 0.3,
#   'rssi': -3.0},
#  {'hex': 'abe65a',
#   'category': 'A3',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 3809,
#   'seen': 120.0,
#   'rssi': -17.7},
#  {'hex': 'ac7160',
#   'alt_baro': 41000,
#   'alt_geom': 42525,
#   'gs': 505.5,
#   'track': 23.7,
#   'geom_rate': 0,
#   'category': 'A2',
#   'lat': 40.048844,
#   'lon': -76.894871,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 33.1,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 6037,
#   'seen': 25.3,
#   'rssi': -18.0},
#  {'hex': 'a36f1d',
#   'category': 'A2',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 2252,
#   'seen': 263.5,
#   'rssi': -15.9},
#  {'hex': 'ab2c04',
#   'flight': 'AAL801  ',
#   'alt_baro': 36000,
#   'alt_geom': 37675,
#   'gs': 397.4,
#   'track': 217.3,
#   'baro_rate': 0,
#   'squawk': '1774',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 36000,
#   'nav_heading': 234.8,
#   'lat': 38.343567,
#   'lon': -77.839011,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 0.2,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 8634,
#   'seen': 0.2,
#   'rssi': -14.8},
#  {'hex': 'a44166',
#   'category': 'A3',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 3826,
#   'seen': 124.3,
#   'rssi': -18.2},
#  {'hex': 'ab30f0',
#   'category': 'A3',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 363,
#   'seen': 171.9,
#   'rssi': -17.0},
#  {'hex': 'a4910c',
#   'category': 'A1',
#   'nav_qnh': 1024.0,
#   'nav_altitude_mcp': 17504,
#   'nav_modes': ['althold'],
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 516,
#   'seen': 39.5,
#   'rssi': -18.0},
#  {'hex': 'a9fc34',
#   'category': 'A3',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 5379,
#   'seen': 228.0,
#   'rssi': -15.4},
#  {'hex': 'acb21b',
#   'category': 'A2',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 5788,
#   'seen': 75.9,
#   'rssi': -18.0},
#  {'hex': 'a1d93b',
#   'category': 'A3',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 4799,
#   'seen': 99.0,
#   'rssi': -17.8},
#  {'hex': 'a3c3e0',
#   'alt_baro': 34000,
#   'alt_geom': 35575,
#   'gs': 407.2,
#   'track': 233.2,
#   'baro_rate': 0,
#   'category': 'A4',
#   'version': 2,
#   'nac_v': 1,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 10168,
#   'seen': 2.3,
#   'rssi': -17.5},
#  {'hex': 'a5d668',
#   'alt_baro': 36000,
#   'alt_geom': 37700,
#   'gs': 400.6,
#   'track': 220.8,
#   'baro_rate': 0,
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 36000,
#   'nav_heading': 239.1,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 10,
#   'nac_v': 2,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 9800,
#   'seen': 0.6,
#   'rssi': -17.0},
#  {'hex': 'a7db41',
#   'flight': 'EJA605  ',
#   'alt_baro': 40000,
#   'alt_geom': 41525,
#   'gs': 337.6,
#   'track': 253.7,
#   'baro_rate': 0,
#   'category': 'A2',
#   'lat': 39.8237,
#   'lon': -78.989669,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 21.4,
#   'version': 2,
#   'nac_v': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 1176,
#   'seen': 19.9,
#   'rssi': -16.3},
#  {'hex': 'ad526c',
#   'flight': 'AAL1802 ',
#   'alt_baro': 35275,
#   'alt_geom': 36850,
#   'gs': 378.7,
#   'track': 253.4,
#   'baro_rate': 1024,
#   'squawk': '1553',
#   'emergency': 'none',
#   'category': 'A3',
#   'nav_qnh': 1013.6,
#   'nav_altitude_mcp': 36000,
#   'nav_heading': 263.0,
#   'lat': 39.031026,
#   'lon': -78.897217,
#   'nic': 8,
#   'rc': 186,
#   'seen_pos': 7.8,
#   'version': 2,
#   'nic_baro': 1,
#   'nac_p': 9,
#   'nac_v': 1,
#   'sil': 3,
#   'sil_type': 'perhour',
#   'gva': 2,
#   'sda': 2,
#   'mlat': [],
#   'tisb': [],
#   'messages': 6181,
#   'seen': 6.4,
#   'rssi': -17.2},
#  {'hex': 'a52844',
#   'category': 'A2',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 10255,
#   'seen': 35.4,
#   'rssi': -14.7},
#  {'hex': 'a08f62',
#   'category': 'A2',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 7563,
#   'seen': 173.8,
#   'rssi': -18.0},
#  {'hex': 'a03f1e',
#   'category': 'A3',
#   'version': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 12370,
#   'seen': 114.3,
#   'rssi': -17.6},
#  {'hex': 'a1696b',
#   'alt_baro': 36000,
#   'alt_geom': 37725,
#   'gs': 381.0,
#   'track': 238.0,
#   'baro_rate': 0,
#   'category': 'A3',
#   'version': 2,
#   'nac_v': 2,
#   'sil_type': 'perhour',
#   'mlat': [],
#   'tisb': [],
#   'messages': 11019,
#   'seen': 17.6,
#   'rssi': -18.2}]
