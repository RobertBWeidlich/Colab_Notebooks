# %% [markdown]
# <a href="https://colab.research.google.com/github/RobertBWeidlich/Colab_Notebooks/blob/main/CnNB_009_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SVM
# from Python Maching Learning, Wei-Meng Lee<br>
# ch. 9

# %%
a = 7
b = 8
c = a + b
print(f"c: {c}")
# Out:
# c: 15

# %%
# !wget https://raw.githubusercontent.com/RobertBWeidlich/Colab_Notebooks/main/svm.csv
# Out:
# --2023-04-24 00:31:13--  https://raw.githubusercontent.com/RobertBWeidlich/Colab_Notebooks/main/svm.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38 [text/plain]
# Saving to: ‘svm.csv’
#
# svm.csv             100%[===================>]      38  --.-KB/s    in 0s
#
# 2023-04-24 00:31:13 (915 KB/s) - ‘svm.csv’ saved [38/38]

# %%
# p. 181
#matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns; sns.set(font_scale=1.2)
import matplotlib as plt

data = pd.read_csv('./svm.csv')
#data = pd.read_csv('./sample_data/mnist_test.csv')
#print(data)
data
# Out:
#    x1  x2  r
# 0   0   0  A
# 1   1   1  A
# 2   2   3  B
# 3   2   0  A
# 4   3   4  B

# %%
print(type(data))
print(data)
sns.lmplot(data=data,
           x="x1", y="x2",
           hue='r',
           palette='Set1',
           fit_reg=False,
           scatter_kws={"s": 50})
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    x1  x2  r
# 0   0   0  A
# 1   1   1  A
# 2   2   3  B
# 3   2   0  A
# 4   3   4  B

# %%
# https://m.tutorialspoint.com/seaborn/seaborn_implot_method.htm#:~:text=Next%20Page-,Seaborn.,multiple%20plots%20can%20be%20plotted.
import seaborn as sns
import matplotlib.pyplot as plt
titanic=sns.load_dataset("titanic")
print(type(titanic))
titanic.head()
sns.lmplot(x="fare", y="age", hue="class",data=titanic)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns; sns.set(font_scale=1.2)
import matplotlib.pyplot as plt

data = pd.read_csv('svm.csv')
sns.lmplot(data=data,
                  x='x1', y='x2',
                   hue='r',
                   palette='Set1',
                   fit_reg=False,
                   scatter_kws={"s": 50});

# %%
# p. 182 - Sunday 4/23/2023
